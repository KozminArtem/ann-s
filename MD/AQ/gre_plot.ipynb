# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x = np.arange(0,10, 0.01)


point = np.array([[2.,5.],[3.,1.],[3.,5.],[4.4,4.6],[7.1,6.3],[7.5,4.],[8.1,8.3],[9.0,8.5],[5.,4.8],[6.,7.]])

# print(point)

plt.figure()
plt.plot(x,x,color = 'green', linewidth = 1)
plt.plot(x,0.75*x,color = 'green', linestyle = '-.')
plt.plot(x,1.25*x,color = 'green', linestyle = '-.')
plt.fill_between(x,0.75*x,1.25*x,facecolor='green',alpha = 0.1)
plt.scatter(point[0][0],point[0][1], facecolor = 'red')
plt.scatter(point[1][0],point[1][1], facecolor = 'red')
plt.scatter(point[2][0],point[2][1], facecolor = 'red')
plt.scatter(point[3][0],point[3][1], facecolor = 'green')
plt.scatter(point[4][0],point[4][1], facecolor = 'green')
plt.scatter(point[5][0],point[5][1], facecolor = 'red')
plt.scatter(point[6][0],point[6][1], facecolor = 'green')
plt.scatter(point[7][0],point[7][1], facecolor = 'green')
plt.scatter(point[8][0],point[8][1], facecolor = 'green')
plt.scatter(point[9][0],point[9][1], facecolor = 'green')

ax = plt.gca()
ax.set_ylabel('Pred CO', fontsize = 12)
ax.set_xlabel('True CO', fontsize = 12)

plt.savefig('fig_AQ/gre_plot.png')

plt.show()
